# %% [markdown]
# #### Question 1
#
# ##### Calculate and write the output of the following expression:
# **30 + 4 × 3 − 6**

# %%
print(30 + 4 * 3 - 6)
# Out:
# 36

# %% [markdown]
# #### Question 2
#
# ##### Calculate and write the output of the following expression:
# **100 ÷ 4 + 7 − 5**

# %%
100 // 4 + 7 - 5
# Out:
# 27

# %% [markdown]
# #### Question 3
#
# ##### Create a variable containing the string value "100". Convert it into an integer and display its data type before and after conversion.

# %%
numb="100"
print("Before Conversion",type(numb))
numb=int(numb)
print("Before Conversion",type(numb))
# Out:
# Before Conversion <class 'str'>
# Before Conversion <class 'int'>

# %% [markdown]
# #### Question 4
#
# ##### Create the following list and display:
# ##### cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]
# ##### Second city
# ##### Fourth city

# %%
cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]
print("Second city",cities[1])
print("Fourth city",cities[3])
# Out:
# Second city Lahore
# Fourth city Peshawar

# %% [markdown]
# #### Question 5
# ##### Create the following nested list and display:
# ##### students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# ##### Ali
# ##### Ayesha

# %%
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
print(students[0][0])
print(students[1][0])
# Out:
# Ali
# Ayesha

# %% [markdown]
# #### Question 6
# ##### Given list:
# ##### numbers = [10, 20, 30, 40, 50, 60, 70]
# ##### Display:
# ##### First 3 elements
# ##### Last 3 elements

# %%
numbers = [10, 20, 30, 40, 50, 60, 70]
print("First 3 elements",numbers[0:3])
print("Last 3 elements",numbers[4:])
# Out:
# First 3 elements [10, 20, 30]
# Last 3 elements [50, 60, 70]

# %% [markdown]
# #### Question 7
# ##### Given nested list::
# ##### students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# ##### Display:
# ##### Name of first student
# ##### Age of second student

# %%
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
print("Name of first student:",students[0][0],"\nAge of second student:",students[1][1])
# Out:
# Name of first student: Ali
# Age of second student: 22

# %% [markdown]
# #### Question 8
# ##### Create a list of 5 fruits and display
# ##### First fruit
# ##### Last fruit

# %%
fruits=["apple","Mango","cherry","orange","pine Apple"]
print("Name of first fruit:",fruits[0],"\nsecond Fruit:",fruits[-1])
# Out:
# Name of first fruit: apple
# second Fruit: pine Apple

# %% [markdown]
# #### Question 9
# ##### Create the following list and display:
# ##### colors = ["Red", "Blue", "Green", "Yellow", "Black"]
# ##### First color
# ##### Last color
# ##### using negative indexing

# %%
colors = ["Red", "Blue", "Green", "Yellow", "Black"]
print("First Color:",colors[-5],"\nLast Color:",colors[-1])
# Out:
# First Color: Red
# Last Color: Black

# %%
colors[-5:] #start to end with negative indexing"
# Out:
# ['Red', 'Blue', 'Green', 'Yellow', 'Black']

# %% [markdown]
# #### Question 10
# ##### Given nested list:
# ##### marks = [["Math", 90], ["Physics", 85], ["English", 88]]
# ##### Display:
# ##### Subject of second student
# ##### Marks of third student

# %%
marks = [["Math", 90], ["Physics", 85], ["English", 88]]
print("Subject of second student:",marks[1][0],"\nMarks of third student:",marks[2][1])
# Out:
# Subject of second student: Physics
# Marks of third student: 88
